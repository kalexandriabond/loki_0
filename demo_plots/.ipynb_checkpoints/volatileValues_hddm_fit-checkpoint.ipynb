# %%
import hddm
import pandas as pd
import matplotlib.pyplot as plt
# !cd /Users/Krista/Documents/github_repositories/testing-master

# %%
data = hddm.load_csv('./test.csv')
data.columns = data.columns.str.strip()
data.head(4)
# Out:
#     rt  response  subj_idx cond
# 0  0.7         0         0   lc
# 1  0.7         0         0   lc
# 2  0.7         0         0   lc
# 3  0.7         0         0   lc

# %%
fig = plt.figure()
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='RT distributions')
for i, subj_data in data.groupby('subj_idx'):
    subj_data.rt.hist(bins=20, histtype='step', ax=ax)

# %%
m_stim = hddm.HDDM(data, depends_on={'v': 'cond', 'a': 'cond'})
m_stim.find_starting_values()
m_stim.sample(10000, burn=1000)
# Out:
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1927: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1932: RuntimeWarning: invalid value encountered in absolute
#   tmp2 = numpy.abs(tmp2)
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1928: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 10001 of 10000 complete in 8446.0 sec
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)

# %%
stats = m_stim.gen_stats()
stats[stats.index.isin(['v(hc)','v(lc)', 'v(hv)','v(lv)'])]
# Out:
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
#            mean        std      2.5q       25q       50q       75q     97.5q  \
# v(hc)  0.818636   0.034913  0.749521  0.795545  0.818806  0.841656   0.88772
# v(hv)  0.197458  0.0351547  0.128478  0.173984  0.197312   0.22088  0.266134
# v(lc)  0.933283  0.0351624   0.86545  0.909673  0.932754  0.956521   1.00361
# v(lv)   1.27492  0.0358439   1.20563   1.25104   1.27435   1.29811   1.34575
#
#             mc err
# v(hc)  0.000409933
# v(hv)  0.000407229
# v(lc)    0.0003467
# v(lv)  0.000451717

# %%
stats[stats.index.isin(['a(hc)','a(lc)', 'a(hv)','a(lv)'])]
# Out:
#           mean        std      2.5q      25q      50q      75q    97.5q  \
# a(hc)  1.19209  0.0613604   1.07267  1.15085  1.19152  1.23307  1.31325
# a(hv)  1.31927  0.0614362   1.20102  1.27818  1.31917  1.36047  1.43821
# a(lc)  1.19486  0.0630029   1.07169  1.15187  1.19448  1.23691  1.32275
# a(lv)  1.11387  0.0634942  0.987112  1.07199  1.11356   1.1556   1.2379
#
#             mc err
# a(hc)  0.000595772
# a(hv)  0.000625356
# a(lc)  0.000631592
# a(lv)  0.000764372

# %%
m_stim.plot_posteriors('a', 'v')
# Out:
# Plotting a(hc)
# Plotting a(hv)
# Plotting a(lc)
# Plotting a(lv)

# %%
v_lc, v_hc = m_stim.nodes_db.node[['v(lc)', 'v(hc)']]
v_lv, v_hv = m_stim.nodes_db.node[['v(lv)', 'v(hv)']]
a_lv, a_hv = m_stim.nodes_db.node[['a(lv)', 'a(hv)']]
a_lc, a_hc = m_stim.nodes_db.node[['a(lc)', 'a(hc)']]

# %%
hddm.analyze.plot_posterior_nodes([v_lc, v_hc])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Posterior of drift-rate group means')

hddm.analyze.plot_posterior_nodes([v_lv, v_hv])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Posterior of drift-rate group means')

hddm.analyze.plot_posterior_nodes([a_lc, a_hc])
plt.xlabel('decision boundary')
plt.ylabel('Posterior probability')
plt.title('Posterior of decision boundary group means')


hddm.analyze.plot_posterior_nodes([a_lv, a_hv])
plt.xlabel('decision boundary')
plt.ylabel('Posterior probability')
plt.title('Posterior of decision boundary group means')
# plt.savefig('hddm_demo_fig_06.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-07870e570a2d> in <module>()
# ----> 1 hddm.analyze.plot_posterior_nodes([v_lc, v_hc],save=True)
#       2 plt.xlabel('drift-rate')
#       3 plt.ylabel('Posterior probability')
#       4 plt.title('Posterior of drift-rate group means')
#       5
#
# TypeError: plot_posterior_nodes() got an unexpected keyword argument 'save'

# %%
# print("P(low_conflict_drift > high_conflict_drift) = ", (v_hc.trace() > v_lc.trace()).mean())
# print("P(low_conflict_bound > high_conflict_bound) = ", (a_hc.trace() > a_lc.trace()).mean())
# print("P(high_volatility_bound > low_volatility_bound) = ", (a_hv.trace() > a_lv.trace()).mean())
# print("P(high_volatility_drift > low_volatility_drift) = ", (v_hv.trace() > v_lv.trace()).mean())
# Out:
# P(low_conflict_drift > high_conflict_drift) =  0.0105555555556
# P(low_conflict_bound > high_conflict_bound) =  0.489666666667

# %%
#for when i fit a null model 
# print "Lumped model DIC: %f" % model.dic
# print("Stimulus model DIC: %f" % m_stim.dic)
# Out:
# Stimulus model DIC: 106755.692790

# %%
#model does not save... db is 'ram' error
# m_stim.save('1000t')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-6c9077e9a4ce> in <module>()
# ----> 1 m_stim.save('1000t')
#
# ~/anaconda/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in save(self, fname)
#     410             * Uses the pickle protocol internally.
#     411         """
# --> 412         pickle.dump(self, open(fname, 'w'))
#     413
#     414     def create_knodes(self):
#
# ~/anaconda/envs/hddm/lib/python3.5/site-packages/hddm/models/base.py in __getstate__(self)
#     690
#     691     def __getstate__(self):
# --> 692         d = super(HDDMBase, self).__getstate__()
#     693         del d['wfpt_class']
#     694
#
# ~/anaconda/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in __getstate__(self)
#     371             dbname = d['mc'].db.__name__
#     372             if (dbname == 'ram'):
# --> 373                     raise ValueError("db is 'ram'. Saving a model requires a database on disk.")
#     374             elif (dbname == 'pickle'):
#     375                     d['dbname'] = d['mc'].db.filename
#
# ValueError: db is 'ram'. Saving a model requires a database on disk.

# %%
 m_stim.print_stats('./1000t_stats.csv')
# Out:
# /Users/Krista/anaconda/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
