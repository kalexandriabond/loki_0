# %% [markdown]
# # Model recovery example with stimulus coding for the starting point for evidence accumulation,  $z$
#   #### Here, $A_z = z$ and $B_z = 1 - z$

# %%
import hddm
from patsy import dmatrix  # for generation of (regression) design matrices
import numpy as np         # for basic matrix operations
from pandas import Series  # to manipulate data-frames generated by hddm
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
import sys
sys.stdout = open('ModelRecoveryOutput_test_stim_coding.txt', 'w')

# %%
#set n subjects and n trials per condition
n_subjects = 10
trials_per_level = 150 # and per stimulus

# %%
#set generative ddm parameters for stimulus A
level1a = {'v':.3, 'a':2, 't':.3,  'z':.5}
level2a = {'v':.4, 'a':2, 't':.3, 'z':.6}
level3a = {'v':.5, 'a':2, 't':.3, 'z':.7}

all_params_stimA = [level1a, level2a, level3a]

# %%
#set generative ddm parameters for stimulus B 
#z for stim B is 1-A_z 
level1b = {'v':.3, 'a':2, 't':.3, 'z':(1-level1a['z'])}
level2b = {'v':.4, 'a':2, 't':.3, 'z':(1-level2a['z'])}
level3b = {'v':.5, 'a':2, 't':.3,'z':(1-level3a['z'])}
all_params_stimB = [level1b, level2b, level3b]

# %%
#generate the data given the above parameters
data_a, params_a = hddm.generate.gen_rand_data({'level1': level1a,
                                                'level2': level2a,
                                                'level3': level3a},
                                                size=trials_per_level,
                                                subjs=n_subjects)
data_b, params_b = hddm.generate.gen_rand_data({'level1': level1b,
                                                'level2': level2b,
                                                'level3': level3b},
                                                size=trials_per_level,
                                                subjs=n_subjects)

# %%
data_a.head(10)
# Out:
#          rt  response  subj_idx condition  stimulus
# 0  1.301343       1.0         0    level3       1.0
# 1  0.749050       0.0         0    level3       1.0
# 2  0.744004       1.0         0    level3       1.0
# 3  0.714742       1.0         0    level3       1.0
# 4  0.391612       1.0         0    level3       1.0
# 5  1.811101       0.0         0    level3       1.0
# 6  0.366794       1.0         0    level3       1.0
# 7  0.670123       1.0         0    level3       1.0
# 8  0.782597       1.0         0    level3       1.0
# 9  2.927301       1.0         0    level3       1.0

# %%
data_b.head(10)
# Out:
#          rt  response  subj_idx condition  stimulus
# 0  0.599324       1.0         0    level3       2.0
# 1  0.904324       0.0         0    level3       2.0
# 2  0.935324       1.0         0    level3       2.0
# 3  0.844324       1.0         0    level3       2.0
# 4  2.476324       1.0         0    level3       2.0
# 5  0.734324       0.0         0    level3       2.0
# 6  0.564324       1.0         0    level3       2.0
# 7  0.880324       1.0         0    level3       2.0
# 8  0.774324       1.0         0    level3       2.0
# 9  1.114324       0.0         0    level3       2.0

# %%
#identify the stimuli 
# a = 1 & b = 2
data_a['stimulus'] = Series(np.ones((len(data_a))), index=data_a.index)
data_b['stimulus'] = Series(np.ones((len(data_b)))*2, index=data_a.index)

# %%
#merge data_a & data_b
mydata = data_a.append(data_b, ignore_index=True)

# %%
#set up the z link function to constrain z from 0:1 
def z_link_func(x, data=mydata):
    stim = (np.asarray(dmatrix('0 + C(s, [[1], [-1]])',
                               {'s': data.stimulus.ix[x.index]}))
    )
    return 1 / (1 + np.exp(-(x * stim)))
#here, stim is 1 & -1 and the result is multiplied appropriately

# %%
#set up the regression model for z 
z_reg = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func}

# %%
#v does not need the logit function because it's unconstrained. 
#though if simulated that way, it could be useful to do that. 

#if data are response coded, then v would need a link function, but only to transform
#drift-rate values associated with stimuli a & b to - & + values, respectively
v_reg = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}

# %%
#the full regression description
reg_descr = [z_reg, v_reg]

# %%
#run the regression model 
m_reg = hddm.HDDMRegressor(mydata, reg_descr, include='z', informative=False)
m_reg.sample(5000, burn=20)
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)

# %%
#compare results to gen. model 
m_reg.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
#                                mean         std       2.5q        25q  \
# a                            2.0809   0.0514583    1.98135    2.04843
# a_std                       0.15646   0.0468608  0.0922164   0.124061
# a_subj.0                    1.92207   0.0311667     1.8619    1.90057
# a_subj.1                    2.06756   0.0314706    2.00641      2.046
# a_subj.2                    2.15656   0.0316492    2.09612    2.13496
# a_subj.3                    1.99533   0.0289931    1.93971     1.9754
# a_subj.4                    2.07984   0.0311598    2.02007     2.0586
# a_subj.5                    2.27832    0.036078    2.20946    2.25367
# a_subj.6                    2.14552   0.0317236    2.08426    2.12412
# a_subj.7                    2.22525   0.0361472    2.15538    2.20056
# a_subj.8                    1.86052   0.0288107    1.80554    1.84072
# a_subj.9                     2.0778   0.0322644    2.01526    2.05561
# t                           0.25613   0.0415571   0.193567   0.229431
# t_std                       0.11591   0.0463891  0.0642162  0.0866374
# t_subj.0                   0.230622  0.00790876   0.214381   0.225519
# t_subj.1                   0.395292  0.00793306   0.378858    0.39002
# t_subj.2                   0.156445   0.0066356   0.142317   0.152231
# t_subj.3                   0.242072  0.00549934   0.230475   0.238475
# t_subj.4                   0.365234  0.00722037   0.350185   0.360518
# t_subj.5                    0.11091  0.00520159   0.099665   0.107717
# t_subj.6                   0.260737  0.00601953     0.2477   0.256996
# t_subj.7                   0.154741  0.00643556   0.141302   0.150585
# t_subj.8                    0.25884   0.0050696   0.248228   0.255601
# t_subj.9                   0.198494  0.00558265   0.186911   0.194933
# z_Intercept                0.121011   0.0182735  0.0879443   0.108276
# z_Intercept_std            0.375594   0.0299421   0.318451   0.355012
# z_Intercept_subj.0        0.0345489  0.00917806  0.0190293  0.0280142
# z_Intercept_subj.1        0.0474454   0.0128726  0.0254586  0.0381727
# z_Intercept_subj.2        0.0598213   0.0163697  0.0322677  0.0483123
# z_Intercept_subj.3         0.103444   0.0270683  0.0560118  0.0840401
# z_Intercept_subj.4          0.13408   0.0322881  0.0749299   0.111507
# z_Intercept_subj.5        0.0926373   0.0247467  0.0497959  0.0749749
# z_Intercept_subj.6        0.0745523   0.0202623  0.0396301  0.0599341
# z_Intercept_subj.7         0.453078   0.0436643   0.367086    0.42334
# z_Intercept_subj.8         0.144383   0.0344304  0.0812601   0.120121
# z_Intercept_subj.9         0.289756   0.0416762   0.208663   0.261678
# z_C(condition)[T.level2]   0.152393   0.0241739   0.105451   0.136162
# z_C(condition)[T.level3]    0.51826   0.0241285   0.471221   0.502065
# v_Intercept                0.276446   0.0668267   0.143547   0.235464
# v_Intercept_std             0.19402   0.0597393   0.115107   0.153218
# v_Intercept_subj.0          0.36364   0.0386202   0.288407   0.337316
# v_Intercept_subj.1         0.302749   0.0363905   0.231805   0.278291
# v_Intercept_subj.2         0.240733   0.0358951   0.170426   0.216941
# v_Intercept_subj.3         0.133633    0.037949  0.0592615   0.108194
# v_Intercept_subj.4       -0.0175337   0.0360737 -0.0895124 -0.0413337
# v_Intercept_subj.5         0.526875   0.0368457   0.454514   0.501589
# v_Intercept_subj.6         0.197222   0.0356097   0.126399   0.173435
# v_Intercept_subj.7         0.438124   0.0368289   0.366414   0.412965
# v_Intercept_subj.8         0.177531   0.0401537  0.0974297   0.150748
# v_Intercept_subj.9         0.395446   0.0377868   0.321104   0.370058
# v_C(condition)[T.level2]   0.109415   0.0258243  0.0595403  0.0917241
# v_C(condition)[T.level3]   0.239194   0.0266654   0.187041   0.221275
#
#                                 50q         75q      97.5q       mc err
# a                           2.08015     2.11215    2.18506  0.000415276
# a_std                       0.14739    0.178515    0.27254  0.000490712
# a_subj.0                    1.92184     1.94295    1.98408  0.000362946
# a_subj.1                    2.06742     2.08859    2.12964  0.000301412
# a_subj.2                    2.15608     2.17757    2.22018  0.000299279
# a_subj.3                    1.99502     2.01507    2.05228  0.000260944
# a_subj.4                    2.07949     2.10077    2.14221  0.000299323
# a_subj.5                    2.27788     2.30248    2.35139    0.0003093
# a_subj.6                    2.14537     2.16663    2.20868  0.000254218
# a_subj.7                    2.22446     2.24964    2.29764  0.000328594
# a_subj.8                    1.86018     1.87991    1.91794  0.000280836
# a_subj.9                    2.07763     2.09958    2.14247  0.000284072
# t                          0.250371    0.275403   0.356254  0.000563287
# t_std                      0.105286    0.131636   0.233593  0.000718689
# t_subj.0                   0.230915    0.236027   0.245305  9.49182e-05
# t_subj.1                   0.395715    0.400776   0.410008  7.68669e-05
# t_subj.2                    0.15686    0.161128    0.16812  5.86136e-05
# t_subj.3                    0.24236    0.245983   0.251857   5.2253e-05
# t_subj.4                   0.365604    0.370241   0.378364  6.98344e-05
# t_subj.5                   0.111312     0.11462   0.119975    4.893e-05
# t_subj.6                   0.261138    0.264942   0.271301  5.01728e-05
# t_subj.7                   0.155077    0.159237    0.16649  8.36476e-05
# t_subj.8                    0.25917    0.262411   0.267939  5.51226e-05
# t_subj.9                   0.198835     0.20239    0.20852  5.35268e-05
# z_Intercept                0.120251    0.132802   0.159057  0.000270858
# z_Intercept_std            0.375205    0.395321   0.436455  0.000305411
# z_Intercept_subj.0        0.0337755   0.0402057  0.0544445  8.84322e-05
# z_Intercept_subj.1        0.0463629   0.0556042  0.0750959  0.000121206
# z_Intercept_subj.2        0.0582437   0.0697884  0.0965085   0.00015429
# z_Intercept_subj.3         0.101438    0.120867   0.161492  0.000318902
# z_Intercept_subj.4         0.132723     0.15476   0.201194  0.000336557
# z_Intercept_subj.5        0.0907227    0.108258   0.146033  0.000255669
# z_Intercept_subj.6        0.0729372   0.0873343   0.118315  0.000201119
# z_Intercept_subj.7          0.45333    0.482794   0.538134  0.000592817
# z_Intercept_subj.8         0.143402    0.167129   0.215793  0.000405469
# z_Intercept_subj.9          0.28978    0.317995   0.372077  0.000475306
# z_C(condition)[T.level2]   0.152174    0.168621   0.200288  0.000277649
# z_C(condition)[T.level3]   0.518297    0.534611   0.565068   0.00030284
# v_Intercept                0.275922    0.317632   0.409105  0.000541409
# v_Intercept_std            0.182402     0.22105   0.341104   0.00060245
# v_Intercept_subj.0          0.36318    0.389918   0.439151  0.000411508
# v_Intercept_subj.1         0.302582    0.327025   0.374711  0.000349244
# v_Intercept_subj.2         0.240794    0.264817   0.310822  0.000358986
# v_Intercept_subj.3         0.133747    0.158978   0.208046  0.000361854
# v_Intercept_subj.4       -0.0172958  0.00706667   0.051679  0.000366127
# v_Intercept_subj.5         0.526919    0.552053   0.598212  0.000365535
# v_Intercept_subj.6         0.197659    0.221362   0.265689  0.000350696
# v_Intercept_subj.7         0.437781    0.463113   0.511255  0.000381475
# v_Intercept_subj.8         0.177654    0.204771    0.25592  0.000359822
# v_Intercept_subj.9         0.395519    0.420851   0.469329  0.000324234
# v_C(condition)[T.level2]   0.109163    0.127052   0.160453  0.000335054
# v_C(condition)[T.level3]   0.239077     0.25702   0.292437  0.000358505

# %%
'gen_param stim A: ', all_params_stimA, 'gen_param stim B: ', all_params_stimB
# Out:
# ('gen_param stim A: ',
#  [{'a': 2, 't': 0.3, 'v': 0.3, 'z': 0.5},
#   {'a': 2, 't': 0.3, 'v': 0.4, 'z': 0.6},
#   {'a': 2, 't': 0.3, 'v': 0.5, 'z': 0.7}],
#  'gen_param stim B: ',
#  [{'a': 2, 't': 0.3, 'v': 0.3, 'z': 0.5},
#   {'a': 2, 't': 0.3, 'v': 0.4, 'z': 0.4},
#   {'a': 2, 't': 0.3, 'v': 0.5, 'z': 0.30000000000000004}])

# %%
#level1_z 
1/(1+np.exp(-(0.121011))) 

#level 2_z 
1/(1+np.exp(-(0.121011 + 0.15))) 

#level 3_z 
1/(1+np.exp(-(0.121011 + 0.52)))
# Out:
# 0.65498196276784049
