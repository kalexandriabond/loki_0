# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import hddm 
from patsy import dmatrix 
import numpy as np
from sys import platform
# print(hddm.__version__)

# %matplotlib inline
# plt.rcParams['figure.figsize'] = 30, 10

# %%
if platform == 'linux':
    home = '/home/krista/'
elif platform == 'darwin': 
    home = '/Users/67981492/'

# %%
orig_df = hddm.load_csv(home + 'Dropbox/loki_0/simple_rt_experiment_probabilityC/analysis/aggregated_data/probC_sim_learning_signals_processed.csv')

# %%
# orig_df2 = hddm.load_csv(home + 'Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/aggregated_data/probC_sim_learning_signals.csv')

# %%
#difference in n_trials later because of removal of trials with rts < .6 s
#note that this uses all data. 
# orig_df2.columns = orig_df2.columns.str.strip()
# orig_df2.shape, orig_df.shape
# Out:
# ((57600, 16), (57600, 19))

# %%
orig_df.columns = orig_df.columns.str.strip()
orig_df = orig_df[orig_df.rt<0.6]
orig_df.reset_index(drop=True, inplace=True)
orig_df.head()
# Out:
#         cpp  target_B  choice_B  cp  gen_drift  gen_bound     rt    acc  \
# 0  0.019881 -0.595781  0.595781   0       -1.0   0.523075  0.172  False
# 1  0.018539 -0.306135  0.306135   0       -1.0   0.519881  0.172  False
# 2  0.268538 -0.139394  0.139394   0       -1.0   0.518539  0.172  False
# 3  0.035630 -0.027685  0.027685   0       -1.0   0.768538  0.172  False
# 4  0.785155 -0.804363  0.804363   0       -1.0   0.535630  0.172  False
#
#    subj_idx   ID        ...         correct_id_choices      b_t0      b_t1  \
# 0         0  761        ...                          1  0.532802  0.226667
# 1         0  761        ...                          1  0.391376  0.251982
# 2         0  761        ...                          1  0.302804  0.275119
# 3         0  761        ...                          1  1.408409  0.604046
# 4         0  761        ...                          1  0.571150  0.635969
#
#        r_t1      r_t2  obs_cp  trial   ideal_B  B_ideal_target  \
# ...

# %%
orig_df.columns
# Out:
# Index(['cpp', 'target_B', 'choice_B', 'cp', 'gen_drift', 'gen_bound', 'rt',
#        'acc', 'subj_idx', 'ID', 'cond', 'id_choices', 'correct_id_choices',
#        'b_t0', 'b_t1', 'r_t1', 'r_t2', 'obs_cp', 'trial', 'ideal_B',
#        'B_ideal_target', 'B_nonideal_target'],
#       dtype='object')

# %%
#use target choice as response 
#include correct target choice as stimulus 
all_sim_data = orig_df.rename(index=str, columns={"id_choices": "response", 
                                                       "correct_id_choices": "stimulus"})
all_sim_data = all_sim_data[['response', 'stimulus', 'rt', 'cond', 'subj_idx', 'target_B', 'cpp']] 
# #use target-based belief in reward difference (b_t0 - b_t1)
all_sim_data = all_sim_data.rename(index=str, columns={'target_B': 'B'})
# all_sim_data = all_sim_data[all_sim_data.rt<0.6]
all_sim_data.reset_index(drop=True, inplace=True)

# %%
all_sim_data_acc_code = orig_df.rename(index=str, columns={"acc": "response", 
                                                      })
all_sim_data_acc_code = all_sim_data_acc_code[['response', 'rt', 'cond', 'subj_idx', 'choice_B', 
                                      'ideal_B','cpp']]
all_sim_data_acc_code = all_sim_data_acc_code.rename(index=str, columns={'choice_B': 'B'})
all_sim_data_acc_code = all_sim_data_acc_code[all_sim_data_acc_code.rt<0.6]
all_sim_data_acc_code.reset_index(drop=True, inplace=True)

# %%
#chck for diff.
sum(all_sim_data_acc_code.response), sum(all_sim_data.response)
# Out:
# (34523, 24753)

# %%
all_sim_data_acc_code.head(10)
# Out:
#    response     rt cond  subj_idx         B   ideal_B       cpp
# 0     False  0.172   hc         0  0.595781 -0.306135  0.019881
# 1     False  0.172   hc         0  0.306135 -0.139394  0.018539
# 2     False  0.172   hc         0  0.139394 -0.027685  0.268538
# 3     False  0.172   hc         0  0.027685 -0.804363  0.035630
# 4     False  0.172   hc         0  0.804363  0.064818  0.785155
# 5     False  0.172   hc         0 -0.064818 -2.800194  0.352873
# 6     False  0.192   hc         0  2.800194  0.557813  0.206726
# 7     False  0.172   hc         0 -0.557813 -1.539093  0.163406
# 8     False  0.452   hc         0  1.539093  0.187173  0.031415
# 9     False  0.172   hc         0 -0.187173  0.786843  0.021635

# %%
all_sim_data.head(10)
# Out:
#    response  stimulus     rt cond  subj_idx         B       cpp
# 0         0         1  0.172   hc         0 -0.595781  0.019881
# 1         0         1  0.172   hc         0 -0.306135  0.018539
# 2         0         1  0.172   hc         0 -0.139394  0.268538
# 3         0         1  0.172   hc         0 -0.027685  0.035630
# 4         0         1  0.172   hc         0 -0.804363  0.785155
# 5         0         1  0.172   hc         0  0.064818  0.352873
# 6         0         1  0.192   hc         0 -2.800194  0.206726
# 7         0         1  0.172   hc         0  0.557813  0.163406
# 8         0         1  0.452   hc         0 -1.539093  0.031415
# 9         0         1  0.172   hc         0  0.187173  0.021635

# %%
#define v link function 
#this will flip the sign of v based on the stimulus column

#this is not what i want
#just look at default (+/- drift terminating on lower/upper bounds)
#this is in line with +/- belief. 
def v_link_func(x, data=all_sim_data):
    stim = (np.asarray(dmatrix('0 + C(s,[[1],[-1]])', {'s':data.stimulus.ix[x.index]})))
#     print('input', x)
#     print('flipped', x*stim)
    return x * stim

# %%
def v_link_func2(v, data=all_sim_data):
    if data.stimulus != data.response:
        v = -abs(v) 
    else if data.stimulus == data.response:
        v = v 
    return v

# %%
test_m = hddm.HDDMRegressor(all_sim_data_acc_code, "v~ideal_B", group_only_regressors=False)
test_m.find_starting_values()
test_m.sample(200,burn=50, thin=10, tune_throughout=False)
test_m.print_stats()
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_ideal_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1927: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1928: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 266.1 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...

# %%
test_m.print_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
ppc_data_test_m  = hddm.utils.post_pred_gen(test_m, append_data=True, samples=50, progress_bar = True)
ppc_compare = hddm.utils.post_pred_stats(all_sim_data_acc_code, ppc_data_test_m)
# Out:
#  [-------------------112%-------------------] 27 of 24 complete in 9970.1 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/utils.py:251: RuntimeWarning: invalid value encountered in greater
#   stats['accuracy'] = lambda x: np.mean(x>0)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/utils.py:254: RuntimeWarning: invalid value encountered in greater
#   stats['mean_ub'] = lambda x: np.mean(x[x>0])
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/utils.py:255: RuntimeWarning: invalid value encountered in greater
#   stats['std_ub'] = lambda x: np.std(x[x>0])
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/utils.py:258: RuntimeWarning: invalid value encountered in greater
#   stats[key+'_ub'] = lambda x, q=q: scoreatpercentile(x[x>0], q) if np.any(x>0) else np.nan
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/utils.py:261: RuntimeWarning: invalid value encountered in less
# ...

# %%
#accuracy coded with choiceB should have a + drift rate coefficient. 
test_acc_code_m = hddm.HDDMRegressor(all_sim_data_acc_code,'v~B', bias=False, include=['a', 'v', 'z', 't'], informative=True)
test_acc_code_m.sample(200,burn=50,dbname='test_acc_code.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 321.0 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#yes, drift has a + correlation with belief if choiceB and acc. coding is used. 
test_acc_code_m.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#accuracy coded with idealB should have a + drift rate coefficient. 
test_acc_code_m_idealB = hddm.HDDMRegressor(all_sim_data_acc_code,'v~ideal_B', bias=False, include=['a', 'v', 'z', 't'], informative=True)
test_acc_code_m_idealB.sample(200,burn=50,dbname='test_acc_code_idealB.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_ideal_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 329.0 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
test_acc_code_m_idealB.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#stim coded with target_B and link function = ? 
#if link function flips v when v is negative and going in the correct direction 
#then the drift rate coeff. should be + 

#is it that v_link func will make drift negative when going toward incorrect boundary?
test_stim_code_link_m = hddm.HDDMRegressor(all_sim_data,{'model':'v~B', 'link_func': v_link_func}, bias=False, include=['a', 'v', 'z', 't'], informative=True)
test_stim_code_link_m.sample(200,burn=50,dbname='test_stim_code_link.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 1139.2 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#is it that v_link func will make drift negative when going toward incorrect boundary?

#this one might be best, without a link -- when B is negative, v should be negative 
test_stim_code_no_link_m = hddm.HDDMRegressor(all_sim_data,{'model':'v~B', 'link_func': lambda x:x}, bias=False, include=['a', 'v', 'z', 't'], informative=True)
test_stim_code_no_link_m.sample(200,burn=50,dbname='test_stim_code_no_link.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 570.6 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#when informative is false, cannot fit the data. 
#After 7,000,000 retries, still no good fit found.

#this one might be best, without a link -- when B is negative, v should be negative 
test_stim_code_no_link_m_inf_false = hddm.HDDMRegressor(all_sim_data,{'model':'v~B', 'link_func': lambda x:x}, bias=False, include=['a', 'v', 'z', 't'], informative=False)
test_stim_code_no_link_m_inf_false.sample(200,burn=50,dbname='test_stim_code_no_link_inf_false.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B']
# After 7.000000 retries, still no good fit found.
# ---------------------------------------------------------------------------
# ZeroProbability                           Traceback (most recent call last)
# <ipython-input-69-eb520b4f61cb> in <module>()
#       3
#       4 #this one might be best, without a link -- when B is negative, v should be negative
# ----> 5 test_stim_code_no_link_m_inf_false = hddm.HDDMRegressor(all_sim_data,{'model':'v~B', 'link_func': lambda x:x}, bias=False, include=['a', 'v', 'z', 't'], informative=False)
#       6 test_stim_code_no_link_m_inf_false.sample(200,burn=50,dbname='test_stim_code_no_link.db', db='pickle')
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/models/hddm_regression.py in __init__(self, data, models, group_only_regressors, keep_regressor_trace, **kwargs)
#     201         self.wfpt_reg_class = deepcopy(wfpt_reg_like)
#     202
# ...

# %%
#test if condition-wise effects are present from fitting 
#should have lower drift in hc & hv 

test_stim_code_no_link_m_cond = hddm.HDDMRegressor(all_sim_data,{'model':'v~B:C(cond)', 'link_func': lambda x:x}, bias=False, include=['a', 'v', 'z', 't'], informative=True)
test_stim_code_no_link_m_cond.sample(200,burn=50,dbname='test_stim_code_no_link_cond.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B:C(cond)[hc]', 'v_B:C(cond)[hv]', 'v_B:C(cond)[lc]', 'v_B:C(cond)[lv]']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 805.4 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
test_stim_code_no_link_m_cond.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))
v_hc, v_hv, v_lc, v_lv = test_stim_code_no_link_m_cond.nodes_db.ix[['v_B:C(cond)[hc]', 'v_B:C(cond)[hv]',
                                                                    'v_B:C(cond)[lc]', 'v_B:C(cond)[lv]'], 'node']


drift_fig=hddm.analyze.plot_posterior_nodes([v_hc, v_hv, v_lc, v_lv])

#these distributions are not very well estimated (see bumpiness) 
#due to small number of samples used for testing.
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#also may be possible to directly access v for all trials and flip appropriately
#and then get the average

# %%
test_stim_code_link_m.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
test_stim_code_no_link_m.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
#last try for informative = False
all_sim_data_truncated = all_sim_data[(all_sim_data.rt < .4) & (all_sim_data.rt > .15)]

# %%
#truncated the data to see if informative = False would work. 
#noticed peaks at 0.4. 

#this one might be best, without a link -- when B is negative, v should be negative 
test_stim_code_no_link_m_inf_false = hddm.HDDMRegressor(all_sim_data_truncated,{'model':'v~B', 'link_func': lambda x:x}, bias=False, include=['a', 'v', 'z', 't'], informative=False)
test_stim_code_no_link_m_inf_false.sample(200,burn=50,dbname='test_stim_code_no_link_inf_false_truncated.db', db='pickle')
# Out:
# Adding these covariates:
# ['v_Intercept', 'v_B']
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 201 of 200 complete in 598.8 sec
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
test_stim_code_no_link_m_inf_false.gen_stats()
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))
v_B = test_stim_code_no_link_m_inf_false.nodes_db.ix[['a'], 'node']


drift_fig=hddm.analyze.plot_posterior_nodes([v_B])
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-01d816a544d4> in <module>()
#       4
#       5
# ----> 6 drift_fig=hddm.analyze.plot_posterior_nodes([v_B])
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/analyze.py in plot_posterior_nodes(nodes, bins, lb, ub)
#      32     figure()
#      33     if lb is None:
# ---> 34         lb = min([min(node.trace()[:]) for node in nodes])
#      35     if ub is None:
# ...

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))
v_hc, v_hv, v_lc, v_lv = test_stim_code_no_link_m_cond.nodes_db.ix[['v_B:C(cond)[hc]', 'v_B:C(cond)[hv]',
                                                                    'v_B:C(cond)[lc]', 'v_B:C(cond)[lv]'], 'node']


drift_fig=hddm.analyze.plot_posterior_nodes([v_hc, v_hv, v_lc, v_lv])

# %% [markdown]
# #### Think that v link function assumes stable reward contingencies. (which is why if link func. is used, overwhelmingly negative drift-rate values because of switch in ideal target).
# #### generally used to assess bias toward one target or another.
# #### Instead, just use stimulus coding without link function, and use signed belief. signed belief + signed drift rate should capture covariance.
