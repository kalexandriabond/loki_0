# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

import hddm
from sys import platform
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
print(hddm.__version__)
# Out:
# 0.6.0

# %%
if platform == 'linux':
    home = '/home/krista/'
elif platform == 'darwin': 
    home = '/Users/67981492/'

# %%
all_obs_data = hddm.load_csv(home + 'Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/aggregated_data/combined_learning_sig_obs_data.csv')

print(all_obs_data.columns)

all_obs_data.loc[all_obs_data.p_id_solution == 111, 'p_id_solution'] = 0
all_obs_data.loc[all_obs_data.p_id_solution == 112, 'p_id_solution'] = 1

all_obs_data.loc[all_obs_data.id_choice == 111, 'id_choice'] = 0
all_obs_data.loc[all_obs_data.id_choice == 112, 'id_choice'] = 1

all_obs_data = all_obs_data.rename(index=str, columns={"id_choice": "response", 
                                                        "ID": "subj_idx", "p_id_solution": "stimulus"})
all_obs_data = all_obs_data[['response', 'stimulus', 'rt', 'condition', 'subj_idx', 'ideal_B', 'cpp']] 
all_obs_data = all_obs_data.rename(index=str, columns={'target_B': 'B'})
# Out:
# Index(['cpp', 'target_B', 'choice_B', 'cp', 'gen_drift', 'gen_bound', 'ID',
#        'b_t0', 'b_t1', 'r_t1', 'r_t2', 'obs_cp', 'ideal_B', 'B_ideal_target',
#        'B_nonideal_target', 'LR_choice', 'obs_LR_accuracy', 'obs_LR_solution',
#        'reward', 'cumulative_reward', 'rt', 'total_trial_time', 'iti',
#        'cp_with_slow_fast', 'obs_cp_with_slow_fast', 'obs_high_val_cue',
#        'ID.1', 'condition', 'coded_condition', 'original_trial', 'epoch_n',
#        'epoch_trial', 'shifted_epoch_trial', 'max_epoch_n',
#        'epoch_trial_zero_idx', 'epoch_trial_one_idx',
#        'shifted_epoch_trial_zero_idx', 'repeat_trial', 'prop_112',
#        'n_epoch_trials', 'p_id_solution', 'obs_low_val_cue', 'id_choice',
#        'p_id_accuracy'],
#       dtype='object')

# %%
all_obs_data.head()
# Out:
#    response  stimulus        rt condition  subj_idx   ideal_B       cpp
# 0         0         0  0.711570        hc       761  0.000000  0.099471
# 1         1         0  0.681410        hc       761 -1.241007  0.035079
# 2         0         0  0.767118        hc       761 -0.595781  0.023075
# 3         1         0  0.507209        hc       761 -0.306135  0.019881
# 4         0         0  0.656259        hc       761 -0.139394  0.018539

# %%
#get all combinations of a,t,v,z 
from itertools import combinations

targets = [{'a':'condition'}, {'t':'condition'}, {'v':'condition'}, {'z':'condition'}]
param_pairs = list(combinations(targets, 2))

print(param_pairs)
print(len(param_pairs))
# Out:
# [({'a': 'condition'}, {'t': 'condition'}), ({'a': 'condition'}, {'v': 'condition'}), ({'a': 'condition'}, {'z': 'condition'}), ({'t': 'condition'}, {'v': 'condition'}), ({'t': 'condition'}, {'z': 'condition'}), ({'v': 'condition'}, {'z': 'condition'})]
# 6

# %%
model_dict = {'a_t': param_pairs[0], 'a_v': param_pairs[1],
'a_z': param_pairs[2], 't_v': param_pairs[3], 
't_z': param_pairs[4], 'v_z': param_pairs[5], 'a': targets[0], 't': targets[1],
             'v': targets[2], 'z': targets[3]}

# %%
n_samples, n_burn = 3000, 500

# %% [markdown]
# ## Flat model

# %%
flat_m=hddm.HDDMStimCoding(all_obs_data, bias=True, stim_col='stimulus', split_param='v')
flat_m.find_starting_values()
flat_m.sample(n_samples, burn=n_burn)

# %%
flat_m.plot_posterior_predictive()

# %% [markdown]
# ## All pairs.

# %%
a_t_m=hddm.HDDMStimCoding(all_obs_data,stim_col='stimulus', split_param='v', depends_on={'a': 'condition', 't': 'condition'}, bias=True)
a_t_m.find_starting_values()
a_t_m.sample(n_samples, burn=n_burn)
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1927: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1928: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
# Warning: Powell optimization failed. Falling back to simplex.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in _partial_optimize(self, optimize_nodes, evaluate_nodes, fall_to_simplex, minimizer, use_basin, debug, minimizer_kwargs, basin_kwargs)
#    1024             try:
# -> 1025                 minimize(opt, init_vals, method=minimizer, options=minimizer_kwargs)
#    1026             except:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     592     elif meth == 'powell':
# --> 593         return _minimize_powell(fun, x0, args, callback, **options)
#     594     elif meth == 'cg':
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2571             fval, x, direc1 = _linesearch_powell(func, x, direc1,
# -> 2572                                                  tol=xtol * 100)
#    2573             if (fx2 - fval) > delta:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in _linesearch_powell(func, p, xi, tol)
#    2364         return func(p + alpha*xi)
# -> 2365     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2366     xi = alpha_min*xi
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in brent(func, args, brack, tol, full_output, maxiter)
#    2075                'maxiter': maxiter}
# -> 2076     res = _minimize_scalar_brent(func, brack, args, **options)
#    2077     if full_output:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    2107     brent.set_bracket(brack)
# -> 2108     brent.optimize()
#    2109     x, fval, nit, nfev = brent.get_result(full_output=True)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in optimize(self)
#    1891         func = self.func
# -> 1892         xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#    1893         _mintol = self._mintol
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in get_bracket_info(self)
#    1865         if brack is None:
# -> 1866             xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    1867         elif len(brack) == 2:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in bracket(func, xa, xb, args, grow_limit, maxiter)
#    2290     _verysmall_num = 1e-21
# -> 2291     fa = func(*(xa,) + args)
#    2292     fb = func(*(xb,) + args)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in myfunc(alpha)
#    2363     def myfunc(alpha):
# -> 2364         return func(p + alpha*xi)
#    2365     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in opt(values)
#     999             for value, node in zip(values, optimize_nodes):
# -> 1000                 node.set_value(value)
#    1001             try:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/PyMCObjects.py in set_value(self, value, force)
#     856             if self.dtype.kind != 'O':
# --> 857                 self._value = asanyarray(value, dtype=self.dtype)
#     858                 self._value.flags['W'] = False
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     524     """
# --> 525     return array(a, dtype, copy=False, order=order, subok=True)
#     526
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-81b57b7857bf> in <module>()
#       1 a_t_m=hddm.HDDMStimCoding(all_obs_data,stim_col='stimulus', split_param='v', depends_on={'a': 'condition', 't': 'condition'}, bias=True)
# ----> 2 a_t_m.find_starting_values()
#       3 a_t_m.sample(n_samples, burn=n_burn)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in find_starting_values(self, *args, **kwargs)
#     974         """
#     975         if self.is_group_model:
# --> 976             self.approximate_map(*args, **kwargs)
#     977         else:
#     978             self.map(*args, **kwargs)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in approximate_map(self, individual_subjs, minimizer, use_basin, fall_to_simplex, cycles, debug, minimizer_kwargs, basin_kwargs)
#    1088             for i in range(len(generations)-1, 0, -1):
#    1089                 if self.is_group_model and individual_subjs and (i == len(generations) - 1):
# -> 1090                     self._approximate_map_subj(fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#    1091                     continue
#    1092                 # Optimize the generation at i-1 evaluated over the generation at i
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in _approximate_map_subj(self, minimizer, use_basin, fall_to_simplex, debug, minimizer_kwargs, basin_kwargs)
#    1037             stoch_nodes = self.nodes_db.ix[(self.nodes_db.subj_idx == subj_idx) & (self.nodes_db.stochastic == True)].node
#    1038             obs_nodes = self.nodes_db.ix[(self.nodes_db.subj_idx == subj_idx) & (self.nodes_db.observed == True)].node
# -> 1039             self._partial_optimize(stoch_nodes, obs_nodes, fall_to_simplex=fall_to_simplex, minimizer=minimizer, use_basin=use_basin, debug=debug, minimizer_kwargs=minimizer_kwargs, basin_kwargs=basin_kwargs)
#    1040
#    1041     def approximate_map(self, individual_subjs=True, minimizer='Powell', use_basin=False, fall_to_simplex=True, cycles=1, debug=False, minimizer_kwargs=None, basin_kwargs=None):
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in _partial_optimize(self, optimize_nodes, evaluate_nodes, fall_to_simplex, minimizer, use_basin, debug, minimizer_kwargs, basin_kwargs)
#    1027                 if fall_to_simplex:
#    1028                     print("Warning: Powell optimization failed. Falling back to simplex.")
# -> 1029                     minimize(opt, init_vals, method='Nelder-Mead', options=minimizer_kwargs)
#    1030                 else:
#    1031                     raise
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     589                       callback=callback, **options)
#     590     elif meth == 'nelder-mead':
# --> 591         return _minimize_neldermead(fun, x0, args, callback, **options)
#     592     elif meth == 'powell':
#     593         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     571         if fxr < fsim[0]:
#     572             xe = (1 + rho * chi) * xbar - rho * chi * sim[-1]
# --> 573             fxe = func(xe)
#     574
#     575             if fxe < fxr:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in opt(values)
#    1001             try:
#    1002                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1003                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1004                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#    1005                 if debug: print(neglogp)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in <listcomp>(.0)
#    1001             try:
#    1002                 logp_optimize = [node.logp for node in optimize_nodes]
# -> 1003                 logp_evaluate = [node.logp for node in evaluate_nodes]
#    1004                 neglogp = -np.sum(logp_optimize) - np.sum(logp_evaluate)
#    1005                 if debug: print(neglogp)
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/PyMCObjects.py in get_logp(self)
#     908         if self.verbose > 0:
#     909             print_('\t' + self.__name__ + ': logp accessed.')
# --> 910         logp = self._logp.get()
#     911
#     912         try:
#
# LazyFunction.pyx in pymc.LazyFunction.LazyFunction.get (pymc/LazyFunction.c:2568)()
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/distributions.py in wrapper(**kwds)
#    2977     def wrapper(**kwds):
#    2978         value = kwds.pop('value')
# -> 2979         return f(value, **kwds)
#    2980
#    2981     if arguments is None:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/likelihoods.py in wfpt_like(x, v, sv, a, z, sz, t, st, p_outlier)
#      50     #create likelihood function
#      51     def wfpt_like(x, v, sv, a, z, sz, t, st, p_outlier=0):
# ---> 52         return hddm.wfpt.wiener_like(x['rt'].values, v, sv, a, z, sz, t, st, p_outlier=p_outlier, **wp)
#      53
#      54
#
# KeyboardInterrupt:

# %%
a_v_m=hddm.HDDMStimCoding(all_obs_data, stim_col='stimulus', split_param='v', depends_on={'a': 'condition', 'v': 'condition'}, bias=True)
a_v_m.find_starting_values()
a_v_m.sample(n_samples, burn=n_burn)
# Out:
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1927: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /home/krista/anaconda3/envs/hddm/lib/python3.5/site-packages/scipy/optimize/optimize.py:1928: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
#  [--                6%                  ] 207 of 3000 complete in 130.1 sec

# %%
a_v_m.print_stats()

# %%
a_v_m.plot_posteriors_conditions()

# %%
a_z_m=hddm.HDDM(all_obs_data, depends_on={'a': 'condition', 'z': 'condition'}, bias=True)
a_z_m.find_starting_values()
a_z_m.sample(n_samples, burn=n_burn)

# %%
#fit hddm model according to above 
t_v_m=hddm.HDDM(all_obs_data, stim_col='stimulus', depends_on={'t': 'condition', 'v': 'condition'}, bias=True)
t_v_m.find_starting_values()
t_v_m.sample(n_samples, burn=n_burn, thin=n_thin)

# %%
#fit hddm model according to above 
t_z_m=hddm.HDDM(all_obs_data, stim_col='stimulus', depends_on={'t': 'condition', 'z': 'condition'}, bias=True)
t_z_m.find_starting_values()
t_z_m.sample(n_samples, burn=n_burn, thin=n_thin)

# %%
#fit hddm model according to above 
v_z_m=hddm.HDDM(all_obs_data, stim_col='stimulus', depends_on={'v': 'condition', 'z': 'condition'}, bias=True)
v_z_m.find_starting_values()
v_z_m.sample(n_samples, burn=n_burn, thin=n_thin)

# %% [markdown]
# ## All single parameters.

# %%
a_m=hddm.HDDM(all_obs_data, depends_on={'a': 'condition'}, bias=True)
a_m.find_starting_values()
a_m.sample(n_samples, burn=n_burn)

# %%
t_m=hddm.HDDM(all_obs_data, depends_on={'t': 'condition'}, bias=True)
t_m.find_starting_values()
t_m.sample(n_samples, burn=n_burn)

# %%
v_m=hddm.HDDM(all_obs_data, depends_on={'v': 'condition'}, bias=True)
v_m.find_starting_values()
v_m.sample(n_samples, burn=n_burn)

# %%
z_m=hddm.HDDM(all_obs_data, depends_on={'z': 'condition'}, bias=True)
z_m.find_starting_values()
z_m.sample(n_samples, burn=n_burn)
