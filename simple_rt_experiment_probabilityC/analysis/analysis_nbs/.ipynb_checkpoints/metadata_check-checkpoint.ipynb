# %%
library(tidyverse)
library(readr)
library(ggplot2)

source("../../../spydr_scripts/functions/get_os.R")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.2     ✔ dplyr   0.7.4
# ✔ tidyr   0.8.0     ✔ stringr 1.2.0
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
os <- get_os()
if (os == 'linux'){home <- '/home/krista/'
} else if(os == 'osx'){home <- '/Users/67981492/'}

data_path = paste0(home,
                  'Dropbox/volatileValues/simple_rt_experiment_probabilityC/data/')
setwd(data_path)

# %%
(files <- dir(path = data_path, pattern = "^[0-9](.*)(_runInfo.csv)$"))
# Out:
#  [1] "0761_cond0_trialset0_runInfo.csv"  "0761_cond1_trialset0_runInfo.csv"
#  [3] "0761_cond2_trialset0_runInfo.csv"  "0761_cond3_trialset0_runInfo.csv"
#  [5] "0762_cond0_trialset1_runInfo.csv"  "0762_cond1_trialset1_runInfo.csv"
#  [7] "0762_cond2_trialset1_runInfo.csv"  "0762_cond3_trialset1_runInfo.csv"
#  [9] "0763_cond0_trialset2_runInfo.csv"  "0763_cond1_trialset2_runInfo.csv"
# [11] "0763_cond2_trialset2_runInfo.csv"  "0763_cond3_trialset2_runInfo.csv"
# [13] "0764_cond0_trialset3_runInfo.csv"  "0764_cond1_trialset3_runInfo.csv"
# [15] "0764_cond2_trialset3_runInfo.csv"  "0764_cond3_trialset3_runInfo.csv"
# [17] "0765_cond0_trialset4_runInfo.csv"  "0765_cond1_trialset4_runInfo.csv"
# [19] "0765_cond2_trialset4_runInfo.csv"  "0765_cond3_trialset4_runInfo.csv"
# [21] "0766_cond0_trialset5_runInfo.csv"  "0766_cond1_trialset5_runInfo.csv"
# [23] "0766_cond2_trialset5_runInfo.csv"  "0766_cond3_trialset5_runInfo.csv"
# [25] "0767_cond0_trialset6_runInfo.csv"  "0767_cond1_trialset6_runInfo.csv"
# [27] "0767_cond2_trialset6_runInfo.csv"  "0767_cond3_trialset6_runInfo.csv"
# [29] "0768_cond0_trialset7_runInfo.csv"  "0768_cond1_trialset7_runInfo.csv"
# [31] "0768_cond2_trialset7_runInfo.csv"  "0768_cond3_trialset7_runInfo.csv"
# [33] "0769_cond0_trialset8_runInfo.csv"  "0769_cond1_trialset8_runInfo.csv"
# [35] "0769_cond2_trialset8_runInfo.csv"  "0769_cond3_trialset8_runInfo.csv"
# [37] "0770_cond0_trialset9_runInfo.csv"  "0770_cond1_trialset9_runInfo.csv"
# [39] "0770_cond2_trialset9_runInfo.csv"  "0770_cond3_trialset9_runInfo.csv"
# [41] "0771_cond0_trialset10_runInfo.csv" "0771_cond1_trialset10_runInfo.csv"
# [43] "0771_cond2_trialset10_runInfo.csv" "0771_cond3_trialset10_runInfo.csv"
# [45] "0772_cond0_trialset11_runInfo.csv" "0772_cond1_trialset11_runInfo.csv"
# [47] "0772_cond2_trialset11_runInfo.csv" "0772_cond3_trialset11_runInfo.csv"
# [49] "0773_cond0_trialset12_runInfo.csv" "0773_cond1_trialset12_runInfo.csv"
# [51] "0773_cond2_trialset12_runInfo.csv" "0773_cond3_trialset12_runInfo.csv"
# [53] "0774_cond0_trialset13_runInfo.csv" "0774_cond1_trialset13_runInfo.csv"
# [55] "0774_cond2_trialset13_runInfo.csv" "0774_cond3_trialset13_runInfo.csv"
# [57] "0775_cond0_trialset14_runInfo.csv" "0775_cond1_trialset14_runInfo.csv"
# [59] "0775_cond2_trialset14_runInfo.csv" "0775_cond3_trialset14_runInfo.csv"
# [61] "0776_cond0_trialset15_runInfo.csv" "0776_cond1_trialset15_runInfo.csv"
# [63] "0776_cond2_trialset15_runInfo.csv" "0776_cond3_trialset15_runInfo.csv"
# [65] "0777_cond0_trialset16_runInfo.csv" "0777_cond1_trialset16_runInfo.csv"
# [67] "0777_cond2_trialset16_runInfo.csv" "0777_cond3_trialset16_runInfo.csv"
# [69] "0778_cond0_trialset17_runInfo.csv" "0778_cond1_trialset17_runInfo.csv"
# [71] "0778_cond2_trialset17_runInfo.csv" "0778_cond3_trialset17_runInfo.csv"
# [73] "0779_cond0_trialset18_runInfo.csv" "0779_cond1_trialset18_runInfo.csv"
# [75] "0779_cond2_trialset18_runInfo.csv" "0779_cond3_trialset18_runInfo.csv"
# [77] "0780_cond0_trialset19_runInfo.csv" "0780_cond1_trialset19_runInfo.csv"
# [79] "0780_cond2_trialset19_runInfo.csv" "0780_cond3_trialset19_runInfo.csv"
# [81] "0781_cond0_trialset20_runInfo.csv" "0781_cond1_trialset20_runInfo.csv"
# [83] "0781_cond2_trialset20_runInfo.csv" "0781_cond3_trialset20_runInfo.csv"
# [85] "0782_cond0_trialset21_runInfo.csv" "0782_cond1_trialset21_runInfo.csv"
# [87] "0782_cond2_trialset21_runInfo.csv" "0782_cond3_trialset21_runInfo.csv"
# [89] "0783_cond0_trialset22_runInfo.csv" "0783_cond1_trialset22_runInfo.csv"
# [91] "0783_cond2_trialset22_runInfo.csv" "0783_cond3_trialset22_runInfo.csv"
# [93] "0784_cond0_trialset23_runInfo.csv" "0784_cond1_trialset23_runInfo.csv"
# [95] "0784_cond2_trialset23_runInfo.csv" "0784_cond3_trialset23_runInfo.csv"

# %%
metadata <- files %>%
  map(read_csv,col_types = cols()) %>%                  
  reduce(rbind)

# %%
(condition = map(files, substr, start=10, stop=10))
metadata$condition = as.numeric(condition)
# Out:
# [[1]]
# [1] "0"
#
# [[2]]
# [1] "1"
#
# [[3]]
# [1] "2"
#
# [[4]]
# [1] "3"
#
# [[5]]
# [1] "0"
#
# [[6]]
# [1] "1"
#
# [[7]]
# [1] "2"
#
# [[8]]
# [1] "3"
#
# [[9]]
# [1] "0"
#
# [[10]]
# [1] "1"
#
# [[11]]
# [1] "2"
#
# [[12]]
# [1] "3"
#
# [[13]]
# [1] "0"
#
# [[14]]
# [1] "1"
#
# [[15]]
# [1] "2"
#
# [[16]]
# [1] "3"
#
# [[17]]
# [1] "0"
#
# [[18]]
# [1] "1"
#
# [[19]]
# [1] "2"
#
# [[20]]
# [1] "3"
#
# [[21]]
# [1] "0"
#
# [[22]]
# [1] "1"
#
# [[23]]
# [1] "2"
#
# [[24]]
# [1] "3"
#
# [[25]]
# [1] "0"
#
# [[26]]
# [1] "1"
#
# [[27]]
# [1] "2"
#
# [[28]]
# [1] "3"
#
# [[29]]
# [1] "0"
#
# [[30]]
# [1] "1"
#
# [[31]]
# [1] "2"
#
# [[32]]
# [1] "3"
#
# [[33]]
# [1] "0"
#
# [[34]]
# [1] "1"
#
# [[35]]
# [1] "2"
#
# [[36]]
# [1] "3"
#
# [[37]]
# [1] "0"
#
# [[38]]
# [1] "1"
#
# [[39]]
# [1] "2"
#
# [[40]]
# [1] "3"
#
# [[41]]
# [1] "0"
#
# [[42]]
# [1] "1"
#
# [[43]]
# [1] "2"
#
# [[44]]
# [1] "3"
#
# [[45]]
# [1] "0"
#
# [[46]]
# [1] "1"
#
# [[47]]
# [1] "2"
#
# [[48]]
# [1] "3"
#
# [[49]]
# [1] "0"
#
# [[50]]
# [1] "1"
#
# [[51]]
# [1] "2"
#
# [[52]]
# [1] "3"
#
# [[53]]
# [1] "0"
#
# [[54]]
# [1] "1"
#
# [[55]]
# [1] "2"
#
# [[56]]
# [1] "3"
#
# [[57]]
# [1] "0"
#
# [[58]]
# [1] "1"
#
# [[59]]
# [1] "2"
#
# [[60]]
# [1] "3"
#
# [[61]]
# [1] "0"
#
# [[62]]
# [1] "1"
#
# [[63]]
# [1] "2"
#
# [[64]]
# [1] "3"
#
# [[65]]
# [1] "0"
#
# [[66]]
# [1] "1"
#
# [[67]]
# [1] "2"
#
# [[68]]
# [1] "3"
#
# [[69]]
# [1] "0"
#
# [[70]]
# [1] "1"
#
# [[71]]
# [1] "2"
#
# [[72]]
# [1] "3"
#
# [[73]]
# [1] "0"
#
# [[74]]
# [1] "1"
#
# [[75]]
# [1] "2"
#
# [[76]]
# [1] "3"
#
# [[77]]
# [1] "0"
#
# [[78]]
# [1] "1"
#
# [[79]]
# [1] "2"
#
# [[80]]
# [1] "3"
#
# [[81]]
# [1] "0"
#
# [[82]]
# [1] "1"
#
# [[83]]
# [1] "2"
#
# [[84]]
# [1] "3"
#
# [[85]]
# [1] "0"
#
# [[86]]
# [1] "1"
#
# [[87]]
# [1] "2"
#
# [[88]]
# [1] "3"
#
# [[89]]
# [1] "0"
#
# [[90]]
# [1] "1"
#
# [[91]]
# [1] "2"
#
# [[92]]
# [1] "3"
#
# [[93]]
# [1] "0"
#
# [[94]]
# [1] "1"
#
# [[95]]
# [1] "2"
#
# [[96]]
# [1] "3"

# %%
#condition codes from experimental script
# if condition == 0:
#         exp_param_file = exp_param_directory + 'lc_' + trialfile_n + '.csv'
#     elif condition == 1:
#         exp_param_file = exp_param_directory + 'hc_' + trialfile_n + '.csv'
#     elif condition == 2:
#         exp_param_file = exp_param_directory + 'hv_' + trialfile_n + '.csv'
#     elif condition == 3:
#         exp_param_file = exp_param_directory + 'lv_' + trialfile_n + '.csv'

#decode conditions
metadata$decoded_condition <- recode(metadata$condition,
  '0' = 'lc',
  '1' = 'hc',
  '2' = 'hv',
  '3' = 'lv', 
  )
#check decoding
metadata$decoded_condition[0:5]; metadata$condition[0:5]
# Out:
# [1] "lc" "hc" "hv" "lv" "lc"
# [1] 0 1 2 3 0

# %%
(subject_number = map(files, substr, start=1, stop=4))
metadata$subject_number = as.numeric(subject_number)
# Out:
# [[1]]
# [1] "0761"
#
# [[2]]
# [1] "0761"
#
# [[3]]
# [1] "0761"
#
# [[4]]
# [1] "0761"
#
# [[5]]
# [1] "0762"
#
# [[6]]
# [1] "0762"
#
# [[7]]
# [1] "0762"
#
# [[8]]
# [1] "0762"
#
# [[9]]
# [1] "0763"
#
# [[10]]
# [1] "0763"
#
# [[11]]
# [1] "0763"
#
# [[12]]
# [1] "0763"
#
# [[13]]
# [1] "0764"
#
# [[14]]
# [1] "0764"
#
# [[15]]
# [1] "0764"
#
# [[16]]
# [1] "0764"
#
# [[17]]
# [1] "0765"
#
# [[18]]
# [1] "0765"
#
# [[19]]
# [1] "0765"
#
# [[20]]
# [1] "0765"
#
# [[21]]
# [1] "0766"
#
# [[22]]
# [1] "0766"
#
# [[23]]
# [1] "0766"
#
# [[24]]
# [1] "0766"
#
# [[25]]
# [1] "0767"
#
# [[26]]
# [1] "0767"
#
# [[27]]
# [1] "0767"
#
# [[28]]
# [1] "0767"
#
# [[29]]
# [1] "0768"
#
# [[30]]
# [1] "0768"
#
# [[31]]
# [1] "0768"
#
# [[32]]
# [1] "0768"
#
# [[33]]
# [1] "0769"
#
# [[34]]
# [1] "0769"
#
# [[35]]
# [1] "0769"
#
# [[36]]
# [1] "0769"
#
# [[37]]
# [1] "0770"
#
# [[38]]
# [1] "0770"
#
# [[39]]
# [1] "0770"
#
# [[40]]
# [1] "0770"
#
# [[41]]
# [1] "0771"
#
# [[42]]
# [1] "0771"
#
# [[43]]
# [1] "0771"
#
# [[44]]
# [1] "0771"
#
# [[45]]
# [1] "0772"
#
# [[46]]
# [1] "0772"
#
# [[47]]
# [1] "0772"
#
# [[48]]
# [1] "0772"
#
# [[49]]
# [1] "0773"
#
# [[50]]
# [1] "0773"
#
# [[51]]
# [1] "0773"
#
# [[52]]
# [1] "0773"
#
# [[53]]
# [1] "0774"
#
# [[54]]
# [1] "0774"
#
# [[55]]
# [1] "0774"
#
# [[56]]
# [1] "0774"
#
# [[57]]
# [1] "0775"
#
# [[58]]
# [1] "0775"
#
# [[59]]
# [1] "0775"
#
# [[60]]
# [1] "0775"
#
# [[61]]
# [1] "0776"
#
# [[62]]
# [1] "0776"
#
# [[63]]
# [1] "0776"
#
# [[64]]
# [1] "0776"
#
# [[65]]
# [1] "0777"
#
# [[66]]
# [1] "0777"
#
# [[67]]
# [1] "0777"
#
# [[68]]
# [1] "0777"
#
# [[69]]
# [1] "0778"
#
# [[70]]
# [1] "0778"
#
# [[71]]
# [1] "0778"
#
# [[72]]
# [1] "0778"
#
# [[73]]
# [1] "0779"
#
# [[74]]
# [1] "0779"
#
# [[75]]
# [1] "0779"
#
# [[76]]
# [1] "0779"
#
# [[77]]
# [1] "0780"
#
# [[78]]
# [1] "0780"
#
# [[79]]
# [1] "0780"
#
# [[80]]
# [1] "0780"
#
# [[81]]
# [1] "0781"
#
# [[82]]
# [1] "0781"
#
# [[83]]
# [1] "0781"
#
# [[84]]
# [1] "0781"
#
# [[85]]
# [1] "0782"
#
# [[86]]
# [1] "0782"
#
# [[87]]
# [1] "0782"
#
# [[88]]
# [1] "0782"
#
# [[89]]
# [1] "0783"
#
# [[90]]
# [1] "0783"
#
# [[91]]
# [1] "0783"
#
# [[92]]
# [1] "0783"
#
# [[93]]
# [1] "0784"
#
# [[94]]
# [1] "0784"
#
# [[95]]
# [1] "0784"
#
# [[96]]
# [1] "0784"

# %%
dim(metadata); head(metadata,2)
# Out:
# [1] 96 17
#   psychopy_version python_version pythonScipyVersion pyglet_version
# 1 1.85.2           2.7.12         0.19.1             1.2.4
# 2 1.85.2           2.7.12         0.19.1             1.2.4
#   pygame_version numpy_version wx_version
# 1 1.9.3          1.13.1        4.0.0b2 gtk3 (phoenix)
# 2 1.9.3          1.13.1        4.0.0b2 gtk3 (phoenix)
#   window_refresh_time_avg_ms begin_time
# 1 33.33220                   2018_04_16 15:21 (Year_Month_Day Hour:Min)
# 2 33.33303                   2018_04_15 20:26 (Year_Month_Day Hour:Min)
#   exp_dir
# 1 /home/coaxlab/Dropbox/volatileValues/simple_rt_experiment_probabilityC
# 2 /home/coaxlab/Dropbox/volatileValues/simple_rt_experiment_probabilityC
#   last_sys_reboot     system_platform         internet_access total_exp_time
# 1 2018-04-16 15:00:00 linux 4.4.0-119-generic True            1084.978
# 2 2018-04-15 20:17:00 linux 4.4.0-119-generic True            1110.367
#   break_time condition subject_number
# 1 12.294594  0         761
# 2  8.273055  1         761

# %%
unique(metadata[,1:7]); unique(metadata[,13]); unique(metadata[,10])
# Out:
#   psychopy_version python_version pythonScipyVersion pyglet_version
# 1 1.85.2           2.7.12         0.19.1             1.2.4
#   pygame_version numpy_version wx_version
# 1 1.9.3          1.13.1        4.0.0b2 gtk3 (phoenix)
#   internet_access
# 1 True
# 2 False (proxies not attempted)
#   exp_dir
# 1 /home/coaxlab/Dropbox/volatileValues/simple_rt_experiment_probabilityC

# %%
metadata$exp_time_min <- metadata$total_exp_time / 60

# %%
exp_time_plt <- ggplot(metadata, aes(exp_time_min)) + 
  geom_histogram(alpha=0.2,color='red',fill='red') 
break_time_plt <- ggplot(metadata, aes(break_time)) + 
  geom_histogram(alpha=0.2,color='green',fill='green') 
refresh_time_plt <- ggplot(metadata, aes(window_refresh_time_avg_ms)) + 
  geom_histogram(alpha=0.2,color='black',fill='black')

# %%
exp_time_plt + labs(x = "total time per condition (m)") + facet_grid( . ~ decoded_condition)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
break_time_plt + labs(x = "break time per condition (s)")+ facet_grid( .~ decoded_condition)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
refresh_time_plt + labs(x = "average window refresh time per condition (s)") + facet_grid(.~ decoded_condition)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
