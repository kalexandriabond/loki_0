# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sys import platform

# %%
if platform == 'linux':
    home = '/home/krista/'
elif platform == 'darwin': 
    home = '/Users/67981492/'

# %%
# !pwd
load_dir = home+'Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/hddm_reg_models/fit_param_suite/observed/'
print(load_dir)
fig_dir = home+'Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/hddm_reg_models/fit_param_suite/observed/obs_figures/'
# Out:
# /home/krista/Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/analysis_nbs
# /home/krista/Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/hddm_reg_models/fit_param_suite/observed/

# %%
single_param_dic_dir = load_dir+'obs_dics/single_param_dics.csv'
double_param_dic_dir = load_dir+'obs_dics/dual_param_dics.csv'
triple_param_dic_dir = load_dir+'obs_dics/triple_param_dics.csv'
flat_param_dic_dir = load_dir+'obs_dics/flat_model_dic.csv'

single_param_dics=pd.read_csv(single_param_dic_dir)
dual_param_dics=pd.read_csv(double_param_dic_dir)
triple_param_dics=pd.read_csv(triple_param_dic_dir)
flat_model_dic=pd.read_csv(flat_param_dic_dir)

# %%
single_param_model_names=['obs_a_alone', 'obs_v_alone', 'obs_tr_alone', 'obs_z_alone']
dual_param_model_names=['obs_a_tr', 'obs_v_tr', 'obs_z_tr']
triple_param_model_names=['obs_a_v_tr', 'obs_z_v_tr']
flat_model_name = ['flat_model']

# %%
all_dics = pd.concat([flat_model_dic, single_param_dics, dual_param_dics, triple_param_dics], axis=1)
all_dics.columns = all_dics.columns.str.strip()

# %%
flat_normalized_dics=all_dics.div(all_dics.flat_model, axis=0) 
flat_subtracted_dics=all_dics.subtract(all_dics.flat_model, axis=0)

# %%
plotting_order = triple_param_model_names + dual_param_model_names + single_param_model_names + flat_model_name

# %%
all_dics
# Out:
#      flat_model   obs_a_alone   obs_v_alone  obs_tr_alone   obs_z_alone  \
# 0 -18183.889954 -18803.562705 -19878.794561 -26556.035625 -18228.155716
#
#        obs_a_tr     obs_v_tr      obs_z_tr    obs_a_v_tr    obs_z_v_tr
# 0 -27702.061693 -28743.07181 -26886.792236 -29516.152122 -29105.265839

# %%
y_min = np.min(all_dics.values) - 1000
y_max = np.max(all_dics.values) + 1000

# %%
sns.set(font_scale=5)  
plt.figure(figsize=(60,30))
ax=sns.barplot(data=all_dics, order=plotting_order)
ax.set(ylabel='DIC')
plt.ylim(y_min, y_max)
ax.xaxis.tick_top()
plt.suptitle('Model fits for observed data')
plt.savefig(fig_dir+'raw_obs_stepwise_dics.pdf')

# %%
transformed_plotting_order = triple_param_model_names + dual_param_model_names + single_param_model_names 
sns.set(font_scale=5)  
plt.figure(figsize=(60,30))
ax=sns.barplot(data=flat_normalized_dics, order=transformed_plotting_order)
ax.set(ylabel='normalized DIC')
ax.xaxis.tick_top()
plt.suptitle('Model fits for observed data')
plt.savefig(fig_dir+'normalized_obs_stepwise_dics.pdf')

# %%
#need only v_tr containing models
sub_y_min = np.min(flat_subtracted_dics.values) - 1000
sub_y_max = np.max(flat_subtracted_dics.values) + 1000

sns.set(font_scale=5)  
plt.figure(figsize=(60,30))
ax=sns.barplot(data=flat_subtracted_dics, order=transformed_plotting_order)
ax.set(ylabel='flat-subtracted DIC')
plt.ylim(sub_y_min, sub_y_max)
ax.xaxis.tick_top()
plt.suptitle('Model fits for observed data')
plt.savefig(fig_dir+'subtracted_obs_stepwise_dics.pdf')

# %%
flat_subtracted_dics
# Out:
#    flat_model  obs_a_alone  obs_v_alone  obs_tr_alone  obs_z_alone  \
# 0         0.0  -619.672751 -1694.904607  -8372.145671   -44.265762
#
#       obs_a_tr      obs_v_tr     obs_z_tr    obs_a_v_tr    obs_z_v_tr
# 0 -9518.171739 -10559.181856 -8702.902282 -11332.262168 -10921.375885

# %%
print(flat_subtracted_dics.obs_a_v_tr.values, flat_subtracted_dics.obs_z_v_tr.values)
flat_subtracted_dics.obs_a_v_tr - flat_subtracted_dics.obs_z_v_tr
# Out:
# [-11332.26216784] [-10921.37588481]
# 0   -410.886283
# dtype: float64

# %% [markdown]
# ## plot the posteriors for the winning model

# %%
worst_model, winning_model = all_dics.idxmax(axis=1)[0], all_dics.idxmin(axis=1)[0]

print('worst_model: ', worst_model, '\nwinning_model: ', winning_model)
# Out:
# worst_model:  flat_model
# winning_model:  obs_a_v_tr

# %%
import hddm 
winning_model=hddm.load(load_dir+winning_model+'_traces_winning')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-6b11d8640e93> in <module>()
#       1 import hddm
# ----> 2 winning_model=hddm.load(load_dir+winning_model+'_traces_winning')
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/utils.py in load(fname)
#      21
#      22     """
# ---> 23     model = pickle.load(open(fname, 'rb'))
#      24     return model
#      25
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/hddm/models/base.py in __setstate__(self, d)
#     697     def __setstate__(self, d):
#     698         self.wfpt_class = hddm.likelihoods.generate_wfpt_stochastic_class(d['wiener_params'], cdf_range=d['cdf_range'])
# --> 699         super(HDDMBase, self).__setstate__(d)
#     700
#     701     def _create_wfpt_parents_dict(self, knodes):
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in __setstate__(self, d)
#     394
#     395         if self.sampled:
# --> 396             self.load_db(d['dbname'], db=d['db'])
#     397             self.gen_stats()
#     398         else:
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/kabuki/hierarchical.py in load_db(self, dbname, verbose, db)
#     820
#     821         # Open database
# --> 822         db = db_loader(dbname)
#     823
#     824         # Create mcmc instance reading from the opened database
#
# ~/anaconda3/envs/hddm/lib/python3.5/site-packages/pymc/database/pickle.py in load(filename)
#      80     Return a Database instance.
#      81     """
# ---> 82     file = open(filename, 'rb')
#      83     container = std_pickle.load(file)
#      84     file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/67981492/Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/hddm_reg_models/fit_param_suite/observed/obs_models/obs_a_v_tr_traces_winning_traces.db'

# %%
load_dir + winning_model + '_traces'
# Out:
# '/home/krista/Dropbox/volatileValues/simple_rt_experiment_probabilityC/analysis/hddm_reg_models/fit_param_suite/observed/obs_a_v_tr_traces'

# %% [markdown]
# ### drift rate

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))
v_hc, v_hv, v_lc, v_lv = winning_model.nodes_db.ix[['v(hc)', 'v(hv)', 'v(lc)', 'v(lv)'], 'node']


drift_fig=hddm.analyze.plot_posterior_nodes([v_hc, v_hv, v_lc, v_lv])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.legend()
plt.savefig(fig_dir+'obs_drift_posterior_winning_model.pdf')

# %% [markdown]
# ### threshold

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))

a_hc, a_hv, a_lc, a_lv = winning_model.nodes_db.ix[['a(hc)', 'a(hv)', 'a(lc)', 'a(lv)'], 'node']


threshold_fig=hddm.analyze.plot_posterior_nodes([a_hc, a_hv, a_lc, a_lv])
plt.xlabel('decision threshold')
plt.ylabel('Posterior probability')
plt.legend()
plt.savefig(fig_dir+'obs_threshold_posterior_winning_model.pdf')

# %% [markdown]
# ### non-decision time

# %%
sns.set(font_scale=1.2)  
plt.figure(figsize=(60,30))

tr_hc, tr_hv, tr_lc, tr_lv = winning_model.nodes_db.ix[['t(hc)', 't(hv)', 't(lc)', 't(lv)'], 'node']


ndt_fig=hddm.analyze.plot_posterior_nodes([tr_hc, tr_hv, tr_lc, tr_lv])
plt.xlabel('non-decision time')
plt.ylabel('Posterior probability')
plt.legend()
plt.savefig(fig_dir+'obs_ndt_posterior_winning_model.pdf')

# %%
# tst hyp. that bound ^ with vol
print("P(HV > LV) = ", (a_hv.trace() > a_lv.trace()).mean())
# tst hyp. that drift increases in lc 
print("P(LC > HC) = ", (v_lc.trace() > v_hc.trace()).mean())

# %%
sns.set_context("paper", font_scale=3)
winning_model.plot_posterior_predictive(figsize=(50,50))
