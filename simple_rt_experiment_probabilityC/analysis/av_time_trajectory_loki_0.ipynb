# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import os, glob
import numpy as np

from IPython.display import Image

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
home = os.path.expanduser('~')
fig_path = '/data/Dropbox/loki_0/simple_rt_experiment_probabilityC/analysis/figures/av_time_plots'
# fig_path = home + figs

# %%
p = np.arange(0.65, .95, .10)
lamb = np.arange(10,40,10)

conditions = [(str(int(i*100)) + str(j)) for i in p for j in lamb]

conditional_fn_patterns = ['*' + str(condition) + '*_time_color.png' for condition in conditions]

collapsed_fn_pattern = ('*all_conditions*_time_color.png')

# %%
n_subjects = 24
n_conditions = 4 

conditional_fig_names = [glob.glob(os.path.join(fig_path, conditional_fn_pattern)) for conditional_fn_pattern in conditional_fn_patterns] 
collapsed_fig_names = glob.glob(os.path.join(fig_path, collapsed_fn_pattern))

# %%
[conditional_fig_names[cond_set].sort() for cond_set, cond in enumerate(conditional_fig_names)]
collapsed_fig_names.sort()

# %%
collapsed_images = [Image(fn, width=1000, height=1000) for fn in collapsed_fig_names]
conditional_images = [Image(fn, width=1000, height=1000) for fn in conditional_fig_names]

# %%
for img_n, img in enumerate(collapsed_images):
    dp.display(collapsed_images[img_n])

# %% [markdown]
# # Decision threshold / drift-rate trajectories

# %% [markdown]
# ### Each figure depicts the trajectory of a and v color-coded by time.

# %%
collapsed_images_ = [Image(collapsed_images[fn], width=1000, height=1000) for fn in range(len(collapsed_images))]
